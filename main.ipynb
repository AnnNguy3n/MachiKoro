# %%
import json
data = json.load(open('gym_MachiKoro/envs/action_space.json'))
data
# Out:
# {'0': ['Wheat Field', 'Wheat Field', 1],
#  '1': ['Wheat Field', 'Livestock Farm', 1],
#  '2': ['Wheat Field', 'Bakery', 1],
#  '3': ['Wheat Field', 'Cafe', 1],
#  '4': ['Wheat Field', 'Convenience Store', 1],
#  '5': ['Wheat Field', 'Forest', 1],
#  '6': ['Wheat Field', 'Cheese Factory', 1],
#  '7': ['Wheat Field', 'Furniture Factory', 1],
#  '8': ['Wheat Field', 'Mine', 1],
#  '9': ['Wheat Field', 'Family Restaurant', 1],
#  '10': ['Wheat Field', 'Apple Orchard', 1],
#  '11': ['Wheat Field', 'Vegetable Market', 1],
#  '12': ['Livestock Farm', 'Wheat Field', 1],
#  '13': ['Livestock Farm', 'Livestock Farm', 1],
#  '14': ['Livestock Farm', 'Bakery', 1],
#  '15': ['Livestock Farm', 'Cafe', 1],
#  '16': ['Livestock Farm', 'Convenience Store', 1],
#  '17': ['Livestock Farm', 'Forest', 1],
#  '18': ['Livestock Farm', 'Cheese Factory', 1],
#  '19': ['Livestock Farm', 'Furniture Factory', 1],
#  '20': ['Livestock Farm', 'Mine', 1],
#  '21': ['Livestock Farm', 'Family Restaurant', 1],
# ...
